# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
def vki_hesapla(kilo, boy):
    return kilo / (boy ** 2)

def vki_siniflandir(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki <= 24.9:
        return "Normal kilolu"
    elif 25 <= vki <= 29.9:
        return "Fazla kilolu"
    elif 30 <= vki <= 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

def veri_giris_platformu():
    try:
        adet = int(input("Kaç kişi için giriş yapacaksınız? "))
    except ValueError:
        print("Lütfen geçerli bir sayı girin.")
        return

    with open("vki_kayitlari.txt", "a", encoding="utf-8") as dosya:
        for i in range(adet):
            print(f"\n{i+1}. Kişi Bilgileri:")
            ad_soyad = input("İsim Soyisim: ")
            
            try:
                yas = int(input("Yaş: "))
                boy = float(input("Boy (metre cinsinden, örn. 1.75): "))
                kilo = float(input("Kilo (kg cinsinden): "))
            except ValueError:
                print("Geçersiz giriş! Sayısal değerler bekleniyor.")
                continue

            vki = vki_hesapla(kilo, boy)
            sinif = vki_siniflandir(vki)

            print(f"{ad_soyad} için VKİ: {vki:.2f} - Sınıf: {sinif}")

            dosya.write(f"{ad_soyad}, Yaş: {yas}, Boy: {boy} m, Kilo: {kilo} kg, VKİ: {vki:.2f}, Sınıf: {sinif}\n")

    print("\nTüm veriler 'vki_kayitlari.txt' dosyasına kaydedildi.")

veri_giris_platformu()
# Out:
# 1. Kişi Bilgileri:
# Sedef Sucu için VKİ: 20.55 - Sınıf: Normal kilolu
#
# 2. Kişi Bilgileri:
# Büşra Yükyapan için VKİ: 22.41 - Sınıf: Normal kilolu
#
# 3. Kişi Bilgileri:
# İpek Can için VKİ: 23.42 - Sınıf: Normal kilolu
#
# Tüm veriler 'vki_kayitlari.txt' dosyasına kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

menu = {
    "Muz": 10,
    "Çilek": 12,
    "Ispanak": 8,
    "Yulaf": 6,
    "Badem Sütü": 7,
    "Chia Tohumu": 5,
    "Protein Tozu": 15,
    "Bal": 4
}

def menuyu_goster():
    print("\n📋 Smoothie Menüsü")
    print("-" * 30)
    for urun, fiyat in menu.items():
        print(f"{urun}: {fiyat}₺")
    print("-" * 30)

def satin_al():
    secilenler = []
    toplam_fiyat = 0

    while True:
        urun = input("İçeceğe eklemek istediğiniz ürünü yazın (bitirmek için 'tamam'): ").title()
        if urun == "Tamam":
            break
        elif urun in menu:
            secilenler.append(urun)
            toplam_fiyat += menu[urun]
            print(f"{urun} eklendi. Ara toplam: {toplam_fiyat}₺")
        else:
            print("❌ Menüde böyle bir ürün yok.")

    if secilenler:
        tarih = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        print(f"\n✅ Sipariş alındı! Toplam tutar: {toplam_fiyat}₺")

        with open("yetbar_log.txt", "a", encoding="utf-8") as dosya:
            dosya.write(f"Tarih: {tarih} | Ürünler: {', '.join(secilenler)} | Toplam: {toplam_fiyat}₺\n")

    else:
        print("Hiçbir ürün seçilmedi.")

def ana_menu():
    print("🍹 YetBar - Smoothie Bank'a Hoş Geldiniz!")
    while True:
        print("\n1 - Menüyü Görüntüle")
        print("2 - Smoothie Satın Al")
        print("3 - Çıkış")
        secim = input("Seçiminiz: ")

        if secim == "1":
            menuyu_goster()
        elif secim == "2":
            satin_al()
        elif secim == "3":
            print("Görüşmek üzere! 👋")
            break
        else:
            print("Geçersiz seçim, lütfen 1-2-3 seçeneklerinden birini girin.")


ana_menu()
# Out:
# 🍹 YetBar - Smoothie Bank'a Hoş Geldiniz!
#
# 1 - Menüyü Görüntüle
# 2 - Smoothie Satın Al
# 3 - Çıkış
#
# 📋 Smoothie Menüsü
# ------------------------------
# Muz: 10₺
# Çilek: 12₺
# Ispanak: 8₺
# Yulaf: 6₺
# Badem Sütü: 7₺
# Chia Tohumu: 5₺
# Protein Tozu: 15₺
# Bal: 4₺
# ------------------------------
#
# 1 - Menüyü Görüntüle
# 2 - Smoothie Satın Al
# 3 - Çıkış
# Muz eklendi. Ara toplam: 10₺
#
# ✅ Sipariş alındı! Toplam tutar: 10₺
#
# 1 - Menüyü Görüntüle
# 2 - Smoothie Satın Al
# 3 - Çıkış
# Görüşmek üzere! 👋
